# %%
import numpy as np
import pandas as pd
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
# seed 값 설정
seed = 0
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
# 데이터 입력
df_pre = pd.read_csv('dataset/41.wine.csv', header=None)
df = df_pre.sample(frac=1)
dataset = df.values
X = dataset[:,0:12]
Y = dataset[:,12]

# %%
# 모델 설정
model = Sequential([
    Dense(30, input_dim=12, activation='relu'),
    Dense(12, activation='relu'),
    Dense(8, activation='relu'),
    Dense(1, activation='sigmoid')
]) 
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 30)                390
# _________________________________________________________________
# dense_9 (Dense)              (None, 12)                372
# _________________________________________________________________
# dense_10 (Dense)             (None, 8)                 104
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 9
# =================================================================
# Total params: 875
# Trainable params: 875
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 모델 컴파일 
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
# 모델 저장 폴더 설정
import os
MODEL_DIR = './mode/'
if not os.path.exists(MODEL_DIR):
    os.mkdir(MODEL_DIR)

# %%
# 모델 저장 조건 설정
modelpath = MODEL_DIR + "wine{epoch:03d}-{val_loss:.4f}.hdf5"

checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1)

# %%
# 모델 실행 및 저장
model.fit(X, Y, validation_split=0.2, epochs=200, batch_size=200, 
          verbose=0, callbacks=[checkpointer])
# Out:
# Epoch 00001: saving model to ./mode/wine001-0.5282.hdf5
#
# Epoch 00002: saving model to ./mode/wine002-0.2459.hdf5
#
# Epoch 00003: saving model to ./mode/wine003-0.2240.hdf5
#
# Epoch 00004: saving model to ./mode/wine004-0.2168.hdf5
#
# Epoch 00005: saving model to ./mode/wine005-0.2112.hdf5
#
# Epoch 00006: saving model to ./mode/wine006-0.2041.hdf5
#
# Epoch 00007: saving model to ./mode/wine007-0.2001.hdf5
#
# Epoch 00008: saving model to ./mode/wine008-0.1945.hdf5
#
# Epoch 00009: saving model to ./mode/wine009-0.1919.hdf5
#
# Epoch 00010: saving model to ./mode/wine010-0.1867.hdf5
#
# Epoch 00011: saving model to ./mode/wine011-0.1839.hdf5
#
# Epoch 00012: saving model to ./mode/wine012-0.1800.hdf5
#
# Epoch 00013: saving model to ./mode/wine013-0.1771.hdf5
#
# Epoch 00014: saving model to ./mode/wine014-0.1732.hdf5
#
# Epoch 00015: saving model to ./mode/wine015-0.1653.hdf5
#
# Epoch 00016: saving model to ./mode/wine016-0.1623.hdf5
#
# Epoch 00017: saving model to ./mode/wine017-0.1593.hdf5
#
# Epoch 00018: saving model to ./mode/wine018-0.1552.hdf5
#
# Epoch 00019: saving model to ./mode/wine019-0.1530.hdf5
#
# Epoch 00020: saving model to ./mode/wine020-0.1487.hdf5
#
# Epoch 00021: saving model to ./mode/wine021-0.1463.hdf5
#
# Epoch 00022: saving model to ./mode/wine022-0.1415.hdf5
#
# Epoch 00023: saving model to ./mode/wine023-0.1381.hdf5
#
# Epoch 00024: saving model to ./mode/wine024-0.1330.hdf5
#
# Epoch 00025: saving model to ./mode/wine025-0.1234.hdf5
#
# Epoch 00026: saving model to ./mode/wine026-0.1248.hdf5
#
# Epoch 00027: saving model to ./mode/wine027-0.1316.hdf5
#
# Epoch 00028: saving model to ./mode/wine028-0.1208.hdf5
#
# Epoch 00029: saving model to ./mode/wine029-0.1161.hdf5
#
# Epoch 00030: saving model to ./mode/wine030-0.1143.hdf5
#
# Epoch 00031: saving model to ./mode/wine031-0.1172.hdf5
#
# Epoch 00032: saving model to ./mode/wine032-0.1103.hdf5
#
# Epoch 00033: saving model to ./mode/wine033-0.1051.hdf5
#
# Epoch 00034: saving model to ./mode/wine034-0.1086.hdf5
#
# Epoch 00035: saving model to ./mode/wine035-0.1036.hdf5
#
# Epoch 00036: saving model to ./mode/wine036-0.1024.hdf5
#
# Epoch 00037: saving model to ./mode/wine037-0.0997.hdf5
#
# Epoch 00038: saving model to ./mode/wine038-0.1005.hdf5
#
# Epoch 00039: saving model to ./mode/wine039-0.0979.hdf5
#
# Epoch 00040: saving model to ./mode/wine040-0.0936.hdf5
#
# Epoch 00041: saving model to ./mode/wine041-0.0975.hdf5
#
# Epoch 00042: saving model to ./mode/wine042-0.0908.hdf5
#
# Epoch 00043: saving model to ./mode/wine043-0.0903.hdf5
#
# Epoch 00044: saving model to ./mode/wine044-0.0986.hdf5
#
# Epoch 00045: saving model to ./mode/wine045-0.0939.hdf5
#
# Epoch 00046: saving model to ./mode/wine046-0.0894.hdf5
#
# Epoch 00047: saving model to ./mode/wine047-0.0996.hdf5
#
# Epoch 00048: saving model to ./mode/wine048-0.0847.hdf5
#
# Epoch 00049: saving model to ./mode/wine049-0.0876.hdf5
#
# Epoch 00050: saving model to ./mode/wine050-0.0865.hdf5
#
# Epoch 00051: saving model to ./mode/wine051-0.0882.hdf5
#
# Epoch 00052: saving model to ./mode/wine052-0.0845.hdf5
#
# Epoch 00053: saving model to ./mode/wine053-0.0804.hdf5
#
# Epoch 00054: saving model to ./mode/wine054-0.0814.hdf5
#
# Epoch 00055: saving model to ./mode/wine055-0.0776.hdf5
#
# Epoch 00056: saving model to ./mode/wine056-0.0810.hdf5
#
# Epoch 00057: saving model to ./mode/wine057-0.0766.hdf5
#
# Epoch 00058: saving model to ./mode/wine058-0.0803.hdf5
#
# Epoch 00059: saving model to ./mode/wine059-0.0780.hdf5
#
# Epoch 00060: saving model to ./mode/wine060-0.0727.hdf5
#
# Epoch 00061: saving model to ./mode/wine061-0.0762.hdf5
#
# Epoch 00062: saving model to ./mode/wine062-0.0715.hdf5
#
# Epoch 00063: saving model to ./mode/wine063-0.0730.hdf5
#
# Epoch 00064: saving model to ./mode/wine064-0.0703.hdf5
#
# Epoch 00065: saving model to ./mode/wine065-0.0727.hdf5
#
# Epoch 00066: saving model to ./mode/wine066-0.0699.hdf5
#
# Epoch 00067: saving model to ./mode/wine067-0.0691.hdf5
#
# Epoch 00068: saving model to ./mode/wine068-0.0715.hdf5
#
# Epoch 00069: saving model to ./mode/wine069-0.0677.hdf5
#
# Epoch 00070: saving model to ./mode/wine070-0.0678.hdf5
#
# Epoch 00071: saving model to ./mode/wine071-0.0665.hdf5
#
# Epoch 00072: saving model to ./mode/wine072-0.0666.hdf5
#
# Epoch 00073: saving model to ./mode/wine073-0.0686.hdf5
#
# Epoch 00074: saving model to ./mode/wine074-0.0650.hdf5
#
# Epoch 00075: saving model to ./mode/wine075-0.0654.hdf5
#
# Epoch 00076: saving model to ./mode/wine076-0.0652.hdf5
#
# Epoch 00077: saving model to ./mode/wine077-0.0754.hdf5
#
# Epoch 00078: saving model to ./mode/wine078-0.0723.hdf5
#
# Epoch 00079: saving model to ./mode/wine079-0.0687.hdf5
#
# Epoch 00080: saving model to ./mode/wine080-0.0631.hdf5
#
# Epoch 00081: saving model to ./mode/wine081-0.0647.hdf5
#
# Epoch 00082: saving model to ./mode/wine082-0.0631.hdf5
#
# Epoch 00083: saving model to ./mode/wine083-0.0655.hdf5
#
# Epoch 00084: saving model to ./mode/wine084-0.0635.hdf5
#
# Epoch 00085: saving model to ./mode/wine085-0.0631.hdf5
#
# Epoch 00086: saving model to ./mode/wine086-0.0635.hdf5
#
# Epoch 00087: saving model to ./mode/wine087-0.0616.hdf5
#
# Epoch 00088: saving model to ./mode/wine088-0.0647.hdf5
#
# Epoch 00089: saving model to ./mode/wine089-0.0604.hdf5
#
# Epoch 00090: saving model to ./mode/wine090-0.0646.hdf5
#
# Epoch 00091: saving model to ./mode/wine091-0.0642.hdf5
#
# Epoch 00092: saving model to ./mode/wine092-0.0632.hdf5
#
# Epoch 00093: saving model to ./mode/wine093-0.0619.hdf5
#
# Epoch 00094: saving model to ./mode/wine094-0.0608.hdf5
#
# Epoch 00095: saving model to ./mode/wine095-0.0590.hdf5
#
# Epoch 00096: saving model to ./mode/wine096-0.0595.hdf5
#
# Epoch 00097: saving model to ./mode/wine097-0.0591.hdf5
#
# Epoch 00098: saving model to ./mode/wine098-0.0586.hdf5
#
# Epoch 00099: saving model to ./mode/wine099-0.0584.hdf5
#
# Epoch 00100: saving model to ./mode/wine100-0.0586.hdf5
#
# Epoch 00101: saving model to ./mode/wine101-0.0572.hdf5
#
# Epoch 00102: saving model to ./mode/wine102-0.0594.hdf5
#
# Epoch 00103: saving model to ./mode/wine103-0.0569.hdf5
#
# Epoch 00104: saving model to ./mode/wine104-0.0600.hdf5
#
# Epoch 00105: saving model to ./mode/wine105-0.0580.hdf5
#
# Epoch 00106: saving model to ./mode/wine106-0.0566.hdf5
#
# Epoch 00107: saving model to ./mode/wine107-0.0599.hdf5
#
# Epoch 00108: saving model to ./mode/wine108-0.0660.hdf5
#
# Epoch 00109: saving model to ./mode/wine109-0.0668.hdf5
#
# Epoch 00110: saving model to ./mode/wine110-0.0603.hdf5
#
# Epoch 00111: saving model to ./mode/wine111-0.0581.hdf5
#
# Epoch 00112: saving model to ./mode/wine112-0.0559.hdf5
#
# Epoch 00113: saving model to ./mode/wine113-0.0567.hdf5
#
# Epoch 00114: saving model to ./mode/wine114-0.0600.hdf5
#
# Epoch 00115: saving model to ./mode/wine115-0.0573.hdf5
#
# Epoch 00116: saving model to ./mode/wine116-0.0560.hdf5
#
# Epoch 00117: saving model to ./mode/wine117-0.0619.hdf5
#
# Epoch 00118: saving model to ./mode/wine118-0.0566.hdf5
#
# Epoch 00119: saving model to ./mode/wine119-0.0559.hdf5
#
# Epoch 00120: saving model to ./mode/wine120-0.0565.hdf5
#
# Epoch 00121: saving model to ./mode/wine121-0.0544.hdf5
#
# Epoch 00122: saving model to ./mode/wine122-0.0607.hdf5
#
# Epoch 00123: saving model to ./mode/wine123-0.0606.hdf5
#
# Epoch 00124: saving model to ./mode/wine124-0.0530.hdf5
#
# Epoch 00125: saving model to ./mode/wine125-0.0562.hdf5
#
# Epoch 00126: saving model to ./mode/wine126-0.0577.hdf5
#
# Epoch 00127: saving model to ./mode/wine127-0.0526.hdf5
#
# Epoch 00128: saving model to ./mode/wine128-0.0528.hdf5
#
# Epoch 00129: saving model to ./mode/wine129-0.0535.hdf5
#
# Epoch 00130: saving model to ./mode/wine130-0.0537.hdf5
#
# Epoch 00131: saving model to ./mode/wine131-0.0538.hdf5
#
# Epoch 00132: saving model to ./mode/wine132-0.0529.hdf5
#
# Epoch 00133: saving model to ./mode/wine133-0.0553.hdf5
#
# Epoch 00134: saving model to ./mode/wine134-0.0620.hdf5
#
# Epoch 00135: saving model to ./mode/wine135-0.0541.hdf5
#
# Epoch 00136: saving model to ./mode/wine136-0.0542.hdf5
#
# Epoch 00137: saving model to ./mode/wine137-0.0661.hdf5
#
# Epoch 00138: saving model to ./mode/wine138-0.0543.hdf5
#
# Epoch 00139: saving model to ./mode/wine139-0.0540.hdf5
#
# Epoch 00140: saving model to ./mode/wine140-0.0536.hdf5
#
# Epoch 00141: saving model to ./mode/wine141-0.0566.hdf5
#
# Epoch 00142: saving model to ./mode/wine142-0.0539.hdf5
#
# Epoch 00143: saving model to ./mode/wine143-0.0553.hdf5
#
# Epoch 00144: saving model to ./mode/wine144-0.0515.hdf5
#
# Epoch 00145: saving model to ./mode/wine145-0.0526.hdf5
#
# Epoch 00146: saving model to ./mode/wine146-0.0516.hdf5
# Epoch 00147: saving model to ./mode/wine147-0.0570.hdf5
#
# Epoch 00148: saving model to ./mode/wine148-0.0575.hdf5
#
# Epoch 00149: saving model to ./mode/wine149-0.0536.hdf5
#
# Epoch 00150: saving model to ./mode/wine150-0.0559.hdf5
#
# Epoch 00151: saving model to ./mode/wine151-0.0626.hdf5
#
# Epoch 00152: saving model to ./mode/wine152-0.0577.hdf5
#
# Epoch 00153: saving model to ./mode/wine153-0.0529.hdf5
#
# Epoch 00154: saving model to ./mode/wine154-0.0555.hdf5
#
# Epoch 00155: saving model to ./mode/wine155-0.0530.hdf5
#
# Epoch 00156: saving model to ./mode/wine156-0.0518.hdf5
#
# Epoch 00157: saving model to ./mode/wine157-0.0511.hdf5
#
# Epoch 00158: saving model to ./mode/wine158-0.0549.hdf5
#
# Epoch 00159: saving model to ./mode/wine159-0.0541.hdf5
#
# Epoch 00160: saving model to ./mode/wine160-0.0588.hdf5
#
# Epoch 00161: saving model to ./mode/wine161-0.0548.hdf5
#
# Epoch 00162: saving model to ./mode/wine162-0.0539.hdf5
#
# Epoch 00163: saving model to ./mode/wine163-0.0511.hdf5
#
# Epoch 00164: saving model to ./mode/wine164-0.0520.hdf5
#
# Epoch 00165: saving model to ./mode/wine165-0.0530.hdf5
#
# Epoch 00166: saving model to ./mode/wine166-0.0507.hdf5
#
# Epoch 00167: saving model to ./mode/wine167-0.0540.hdf5
#
# Epoch 00168: saving model to ./mode/wine168-0.0545.hdf5
#
# Epoch 00169: saving model to ./mode/wine169-0.0493.hdf5
#
# Epoch 00170: saving model to ./mode/wine170-0.0535.hdf5
#
# Epoch 00171: saving model to ./mode/wine171-0.0540.hdf5
#
# Epoch 00172: saving model to ./mode/wine172-0.0502.hdf5
#
# Epoch 00173: saving model to ./mode/wine173-0.0513.hdf5
#
# Epoch 00174: saving model to ./mode/wine174-0.0521.hdf5
#
# Epoch 00175: saving model to ./mode/wine175-0.0543.hdf5
#
# Epoch 00176: saving model to ./mode/wine176-0.0509.hdf5
#
# Epoch 00177: saving model to ./mode/wine177-0.0524.hdf5
#
# Epoch 00178: saving model to ./mode/wine178-0.0529.hdf5
#
# Epoch 00179: saving model to ./mode/wine179-0.0682.hdf5
#
# Epoch 00180: saving model to ./mode/wine180-0.0512.hdf5
#
# Epoch 00181: saving model to ./mode/wine181-0.0531.hdf5
#
# Epoch 00182: saving model to ./mode/wine182-0.0503.hdf5
#
# Epoch 00183: saving model to ./mode/wine183-0.0507.hdf5
#
# Epoch 00184: saving model to ./mode/wine184-0.0498.hdf5
#
# Epoch 00185: saving model to ./mode/wine185-0.0522.hdf5
#
# Epoch 00186: saving model to ./mode/wine186-0.0512.hdf5
#
# Epoch 00187: saving model to ./mode/wine187-0.0519.hdf5
#
# Epoch 00188: saving model to ./mode/wine188-0.0571.hdf5
#
# Epoch 00189: saving model to ./mode/wine189-0.0514.hdf5
#
# Epoch 00190: saving model to ./mode/wine190-0.0562.hdf5
#
# Epoch 00191: saving model to ./mode/wine191-0.0486.hdf5
#
# Epoch 00192: saving model to ./mode/wine192-0.0493.hdf5
#
# Epoch 00193: saving model to ./mode/wine193-0.0498.hdf5
#
# Epoch 00194: saving model to ./mode/wine194-0.0500.hdf5
#
# Epoch 00195: saving model to ./mode/wine195-0.0502.hdf5
#
# Epoch 00196: saving model to ./mode/wine196-0.0500.hdf5
#
# Epoch 00197: saving model to ./mode/wine197-0.0541.hdf5
#
# Epoch 00198: saving model to ./mode/wine198-0.0494.hdf5
#
# Epoch 00199: saving model to ./mode/wine199-0.0513.hdf5
#
# Epoch 00200: saving model to ./mode/wine200-0.0499.hdf5
