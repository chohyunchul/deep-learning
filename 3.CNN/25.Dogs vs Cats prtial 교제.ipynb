# %%
import numpy as np
from glob import glob
import cv2, os, random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
path = 'dataset/train'

# %%
ROW, COL = 96, 96

dogs, cats = [], []
y_dogs, y_cats = [], []

# %%
dog_path = os.path.join(path, 'dog.5*')
len(glob(dog_path))
# Out:
# 1111

# %%
## Load some our dog images (1,111 개 이미지)
dog_path = os.path.join(path, 'dog.5*')
for dog_img in glob(dog_path):
    dog = cv2.imread(dog_img)
    dog = cv2.cvtColor(dog, cv2.COLOR_BGR2GRAY)
    dog = cv2.resize(dog, (ROW, COL))
    dog = image.img_to_array(dog)
    dogs.append(dog)

# %%
cat_path = os.path.join(path, 'cat.5*')
for cat_img in glob(cat_path):
    cat = cv2.imread(cat_img)
    cat = cv2.cvtColor(cat, cv2.COLOR_BGR2GRAY)
    cat = cv2.resize(cat, (ROW, COL))
    cat = image.img_to_array(cat)
    cats.append(cat)

# %%
classes = ['dog', 'cat']

# %%
plt.figure(figsize=(12,8))    
for i in range(5):
    plt.subplot(1, 5, i+1)
    img = image.array_to_img(random.choice(dogs))
    plt.imshow(img, cmap=plt.get_cmap('gray'))

    plt.axis('off')
    plt.title('It should be a {}.'.format(classes[0]))        
plt.show()

# %%
plt.figure(figsize=(12,8))
for i in range(5):
    plt.subplot(1, 5, i+1)
    img = image.array_to_img(random.choice(cats))
    plt.imshow(img, cmap=plt.get_cmap('gray'))

    plt.axis('off')
    plt.title('It should be a {}.'.format(classes[1]))
plt.show()

# %%
y_dogs = [1 for item in enumerate(dogs)]
y_cats = [0 for item in enumerate(cats)]

# %%
## converting everything to Numpy array to fit in our model
## them creating a X and target file like we used to see
## in Machine and Deep Learning models
dogs = np.asarray(dogs).astype('float32') / 255
cats = np.asarray(cats).astype('float32') / 255
y_dogs = np.asarray(y_dogs).astype('int32')
y_cats = np.asarray(y_cats).astype('int32')

# %%
X = np.concatenate((dogs,cats), axis=0)
y = np.concatenate((y_dogs, y_cats), axis=0)

# %%
len(X)
# Out:
# 2222

# %%
## One-Hot Encoding
y = tf.keras.utils.to_categorical(y, 2)

# %%
## Here is our model as a CNN
model = Sequential([
    Conv2D(32, (3,3), padding='same', input_shape=(ROW, COL, 1), 
           activation='relu'),
    Conv2D(32, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.25),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(.5),
    Dense(2, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 96, 96, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 96, 96, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 48, 48, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 48, 48, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 48, 48, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 48, 48, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24, 24, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 36864)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               18874880
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 18,940,898
# Trainable params: 18,940,898
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', 
              optimizer=Adam(), metrics=['accuracy'])

# %%
modelpath = "model/dogs_vs_cats-cnn-{epoch:02d}-{val_loss:.4f}.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', 
                               verbose=1, save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10)

# %%
model.fit(X, y, batch_size=32, epochs=40, validation_split=0.2,
          callbacks=[checkpointer, early_stopping_callback])
# Out:
# Train on 1777 samples, validate on 445 samples
# Epoch 1/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.7175 - accuracy: 0.6011
# Epoch 00001: val_loss improved from inf to 0.75439, saving model to model/dogs_vs_cats-cnn-01-0.7544.hdf5
# 1777/1777 [==============================] - 51s 29ms/sample - loss: 0.7171 - accuracy: 0.6016 - val_loss: 0.7544 - val_accuracy: 0.0000e+00
# Epoch 2/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6602 - accuracy: 0.6278
# Epoch 00002: val_loss did not improve from 0.75439
# 1777/1777 [==============================] - 48s 27ms/sample - loss: 0.6609 - accuracy: 0.6252 - val_loss: 0.8759 - val_accuracy: 0.0000e+00
# Epoch 3/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6528 - accuracy: 0.6273
# Epoch 00003: val_loss did not improve from 0.75439
# 1777/1777 [==============================] - 48s 27ms/sample - loss: 0.6534 - accuracy: 0.6258 - val_loss: 0.9405 - val_accuracy: 0.0000e+00
# Epoch 4/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6485 - accuracy: 0.6244
# Epoch 00004: val_loss did not improve from 0.75439
# 1777/1777 [==============================] - 47s 26ms/sample - loss: 0.6487 - accuracy: 0.6258 - val_loss: 0.7623 - val_accuracy: 0.0000e+00
# Epoch 5/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6459 - accuracy: 0.6278
# Epoch 00005: val_loss did not improve from 0.75439
# 1777/1777 [==============================] - 48s 27ms/sample - loss: 0.6461 - accuracy: 0.6286 - val_loss: 0.7931 - val_accuracy: 0.0202
# Epoch 6/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6432 - accuracy: 0.6511
# Epoch 00006: val_loss improved from 0.75439 to 0.75276, saving model to model/dogs_vs_cats-cnn-06-0.7528.hdf5
# 1777/1777 [==============================] - 48s 27ms/sample - loss: 0.6434 - accuracy: 0.6517 - val_loss: 0.7528 - val_accuracy: 0.1034
# Epoch 7/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6441 - accuracy: 0.6625
# Epoch 00007: val_loss did not improve from 0.75276
# 1777/1777 [==============================] - 47s 27ms/sample - loss: 0.6462 - accuracy: 0.6601 - val_loss: 0.8147 - val_accuracy: 0.2876
# Epoch 8/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6360 - accuracy: 0.6597
# Epoch 00008: val_loss did not improve from 0.75276
# 1777/1777 [==============================] - 47s 27ms/sample - loss: 0.6360 - accuracy: 0.6612 - val_loss: 0.7958 - val_accuracy: 0.2787
# Epoch 9/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6305 - accuracy: 0.6562
# Epoch 00009: val_loss did not improve from 0.75276
# 1777/1777 [==============================] - 48s 27ms/sample - loss: 0.6300 - accuracy: 0.6567 - val_loss: 0.8976 - val_accuracy: 0.2449
# Epoch 10/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6041 - accuracy: 0.6756
# Epoch 00010: val_loss improved from 0.75276 to 0.75239, saving model to model/dogs_vs_cats-cnn-10-0.7524.hdf5
# 1777/1777 [==============================] - 49s 28ms/sample - loss: 0.6044 - accuracy: 0.6747 - val_loss: 0.7524 - val_accuracy: 0.4472
# Epoch 11/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.5692 - accuracy: 0.6955
# Epoch 00011: val_loss did not improve from 0.75239
# 1777/1777 [==============================] - 47s 26ms/sample - loss: 0.5674 - accuracy: 0.6972 - val_loss: 1.2362 - val_accuracy: 0.2809
# Epoch 12/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.5519 - accuracy: 0.7108
# Epoch 00012: val_loss did not improve from 0.75239
# 1777/1777 [==============================] - 47s 26ms/sample - loss: 0.5522 - accuracy: 0.7113 - val_loss: 0.7963 - val_accuracy: 0.4404
# Epoch 13/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.4969 - accuracy: 0.7426
# Epoch 00013: val_loss did not improve from 0.75239
# 1777/1777 [==============================] - 47s 27ms/sample - loss: 0.4953 - accuracy: 0.7434 - val_loss: 0.9101 - val_accuracy: 0.4562
# Epoch 14/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.4283 - accuracy: 0.7926
# Epoch 00014: val_loss improved from 0.75239 to 0.72900, saving model to model/dogs_vs_cats-cnn-14-0.7290.hdf5
# 1777/1777 [==============================] - 49s 27ms/sample - loss: 0.4276 - accuracy: 0.7935 - val_loss: 0.7290 - val_accuracy: 0.6090
# Epoch 15/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.3939 - accuracy: 0.8080
# Epoch 00015: val_loss did not improve from 0.72900
# 1777/1777 [==============================] - 47s 27ms/sample - loss: 0.3932 - accuracy: 0.8087 - val_loss: 0.9201 - val_accuracy: 0.5573
# Epoch 16/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.3139 - accuracy: 0.8591
# Epoch 00016: val_loss did not improve from 0.72900
# 1777/1777 [==============================] - 48s 27ms/sample - loss: 0.3152 - accuracy: 0.8582 - val_loss: 0.8670 - val_accuracy: 0.6247
# Epoch 17/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.2379 - accuracy: 0.8943
# Epoch 00017: val_loss did not improve from 0.72900
# 1777/1777 [==============================] - 47s 26ms/sample - loss: 0.2376 - accuracy: 0.8948 - val_loss: 1.2134 - val_accuracy: 0.6090
# Epoch 18/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.1629 - accuracy: 0.9398
# Epoch 00018: val_loss did not improve from 0.72900
# 1777/1777 [==============================] - 48s 27ms/sample - loss: 0.1625 - accuracy: 0.9403 - val_loss: 1.3881 - val_accuracy: 0.6067
# Epoch 19/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.1345 - accuracy: 0.9540
# Epoch 00019: val_loss did not improve from 0.72900
# 1777/1777 [==============================] - 47s 26ms/sample - loss: 0.1337 - accuracy: 0.9544 - val_loss: 1.7727 - val_accuracy: 0.5573
# Epoch 20/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.1049 - accuracy: 0.9602
# Epoch 00020: val_loss did not improve from 0.72900
# 1777/1777 [==============================] - 47s 27ms/sample - loss: 0.1048 - accuracy: 0.9600 - val_loss: 2.3498 - val_accuracy: 0.5258
# Epoch 21/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.1029 - accuracy: 0.9670
# Epoch 00021: val_loss did not improve from 0.72900
# 1777/1777 [==============================] - 47s 26ms/sample - loss: 0.1040 - accuracy: 0.9662 - val_loss: 1.8038 - val_accuracy: 0.5124
# Epoch 22/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0771 - accuracy: 0.9733
# Epoch 00022: val_loss did not improve from 0.72900
# 1777/1777 [==============================] - 47s 26ms/sample - loss: 0.0768 - accuracy: 0.9736 - val_loss: 1.6562 - val_accuracy: 0.6112
# Epoch 23/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0362 - accuracy: 0.9881
# Epoch 00023: val_loss did not improve from 0.72900
# 1777/1777 [==============================] - 47s 27ms/sample - loss: 0.0358 - accuracy: 0.9882 - val_loss: 2.2946 - val_accuracy: 0.5775
# Epoch 24/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0479 - accuracy: 0.9847
# Epoch 00024: val_loss did not improve from 0.72900
# 1777/1777 [==============================] - 47s 27ms/sample - loss: 0.0475 - accuracy: 0.9848 - val_loss: 2.4415 - val_accuracy: 0.4854

# %%
from tensorflow.keras.models import load_model
#del model
model = load_model('model/dogs_vs_cats-cnn-14-0.7290.hdf5')

# %%
scores = model.evaluate(X, y, verbose=2)
print('MODEL ACCURACY: %.5f' % scores[1])
# Out:
# 2222/2222 - 6s - loss: 0.4424 - accuracy: 0.7957
# MODEL ACCURACY: 0.79568
