# %% [markdown]
# # Dogs vs Cats

# %% [markdown]
# # Kaggle Dataset의 일부를 이용한 개, 고양이 구분

# %% [markdown]
# # Dog Image:1,111개, Cat image:1,111개, 총 2,222개

# %% [markdown]
# # 출처 : pontoregende GitHub

# %%
import numpy as np
from glob import glob
import cv2, os, random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
path = 'dataset/train'

# %%
# seed 값 설정
seed = 0
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# ## Train set 만들기

# %%
## used for resize and in our model
ROW, COL = 96, 96  # 사진마다 사이즈가 달라서 통일시켜준다
 
dogs, cats = [], []    # x y 파일을 준비한다.
y_dogs, y_cats = [], []

# %%
dog_path = os.path.join(path, 'dog.5*')   # 도그 5 몇개가 있는지 확인한다.
len(glob(dog_path))
# Out:
# 1111

# %%
## Load some our dog images (1,111 개 이미지)
dog_path = os.path.join(path, 'dog.5*')
for dog_img in glob(dog_path):
    dog = cv2.imread(dog_img)  # 이미지 일고
    dog = cv2.cvtColor(dog, cv2.COLOR_BGR2GRAY)  # 컬러 입히고
    dog = cv2.resize(dog, (ROW, COL))  # 96 사이즈로 리사이즈
    dog = image.img_to_array(dog)
    dogs.append(dog)

# %%
## Load some our cat images (1,111 개 이미지)
cat_path = os.path.join(path, 'cat.5*')
for cat_img in glob(cat_path):
    cat = cv2.imread(cat_img)
    cat = cv2.cvtColor(cat, cv2.COLOR_BGR2GRAY)
    cat = cv2.resize(cat, (ROW, COL))
    cat = image.img_to_array(cat)
    cats.append(cat)

# %%
classes = ['dog', 'cat']

# %%
# 이미지가 제대로 들어갔는지 확인한다.
plt.figure(figsize=(12,8))
for i in range(5):
    plt.subplot(1, 5, i+1)
    img = image.array_to_img(random.choice(dogs))
    plt.imshow(img, cmap=plt.get_cmap('gray'))
    
    plt.axis('off')
    plt.title('It should be a {}.'.format(classes[0]))
plt.show()

# %%
plt.figure(figsize=(12,8))
for i in range(5):
    plt.subplot(1, 5, i+1)
    img = image.array_to_img(random.choice(cats))
    plt.imshow(img, cmap=plt.get_cmap('gray'))

    plt.axis('off')
    plt.title('It should be a {}.'.format(classes[1]))
plt.show()

# %%
## just change the labels for 0 and  1   # 사진 파일은 0과 1로 변경한다.
y_dogs =[1 for item in enumerate(dogs)]
y_cats =[0 for item in enumerate(cats)]

# %%
y_dogs[0], y_cats[0]
# Out:
# (1, 0)

# %%
## converting everything to Numpy array to fit in our model
## them creating a X and target file like we used to see
## in Machine and Deep Learning models
dogs = np.asarray(dogs).astype('float32') / 255
cats = np.asarray(cats).astype('float32') / 255
y_dogs = np.asarray(y_dogs).astype('int32')
y_cats = np.asarray(y_cats).astype('int32')

# %%
X_train = np.concatenate((dogs,cats), axis=0)
Y_train = np.concatenate((y_dogs, y_cats), axis=0)

# %%
len(X_train)
# Out:
# 2222

# %%
## One hot Encoding
Y_train = tf.keras.utils.to_categorical(Y_train,2)

# %% [markdown]
# # test set doa vs cat 만들기

# %%
dogs, cats = [], []    # x y 파일을 준비한다.
y_dogs, y_cats = [], []

# %%
dog_path = os.path.join(path, 'cat.12*')   # 도그 5 몇개가 있는지 확인한다.
len(glob(dog_path))
# Out:
# 611

# %%
## Load some our dog images (1,111 개 이미지)
dog_path = os.path.join(path, 'dog.12*')
for dog_img in glob(dog_path):
    dog = cv2.imread(dog_img)  # 이미지 일고
    dog = cv2.cvtColor(dog, cv2.COLOR_BGR2GRAY)  # 컬러 입히고
    dog = cv2.resize(dog, (ROW, COL))  # 96 사이즈로 리사이즈
    dog = image.img_to_array(dog)
    dogs.append(dog)

# %%
## Load some our cat images (1,111 개 이미지)
cat_path = os.path.join(path, 'cat.12*')
for cat_img in glob(cat_path):
    cat = cv2.imread(cat_img)
    cat = cv2.cvtColor(cat, cv2.COLOR_BGR2GRAY)
    cat = cv2.resize(cat, (ROW, COL))
    cat = image.img_to_array(cat)
    cats.append(cat)

# %%
classes1 = ['dog', 'cat']

# %%
# 이미지가 제대로 들어갔는지 확인한다.
plt.figure(figsize=(12,8))
for i in range(5):
    plt.subplot(1, 5, i+1)
    img = image.array_to_img(random.choice(dogs))
    plt.imshow(img, cmap=plt.get_cmap('gray'))
    
    plt.axis('off')
    plt.title('It should be a {}.'.format(classes1[0]))
plt.show()

# %%
plt.figure(figsize=(12,8))
for i in range(5):
    plt.subplot(1, 5, i+1)
    img = image.array_to_img(random.choice(cats))
    plt.imshow(img, cmap=plt.get_cmap('gray'))

    plt.axis('off')
    plt.title('It should be a {}.'.format(classes1[1]))
plt.show()

# %%
y_dogs =[1 for item in enumerate(dogs)]
y_cats =[0 for item in enumerate(cats)]

# %%
## converting everything to Numpy array to fit in our model
## them creating a X and target file like we used to see
## in Machine and Deep Learning models
dogs = np.asarray(dogs).astype('float32') / 255
cats = np.asarray(cats).astype('float32') / 255
y_dogs = np.asarray(y_dogs).astype('int32')
y_cats = np.asarray(y_cats).astype('int32')

# %%
dogs.shape
# Out:
# (611, 96, 96, 1)

# %%
X_test = np.concatenate((dogs,cats), axis=0)
Y_test = np.concatenate((y_dogs, y_cats), axis=0)

# %%
len(X_test)
# Out:
# 1222

# %%
## One hot Encoding
Y_test = tf.keras.utils.to_categorical(Y_test,2)

# %%
## here is our model as a CNN
model = Sequential([
    Conv2D(32, (3,3), padding='same', input_shape=(ROW, COL, 1), 
           activation='relu'),
    Conv2D(32, (3,3), padding='same', activation='elu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.25),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(.5),
    Dense(2, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 96, 96, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 96, 96, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 48, 48, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 48, 48, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 48, 48, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 48, 48, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24, 24, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 36864)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               18874880
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 18,940,898
# Trainable params: 18,940,898
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 'adam' Adam() 두가지 방법이 있음
model.compile(loss='categorical_crossentropy', 
              optimizer=Adam(), metrics=['accuracy'])

# %%
# to save checkpoint to use later
modelpath = "model/dogs_vs_cats-cnn-{epoch:02d}-{val_loss:.4f}.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', 
                               verbose=1, save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10)

# %% [markdown]
# # 모델 학습

# %%
model.fit(X_train, Y_train, batch_size=32, epochs=40, validation_split=0.2,
          callbacks=[checkpointer,early_stopping_callback])
# Out:
# Train on 1777 samples, validate on 445 samples
# Epoch 1/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6926 - accuracy: 0.6148
# Epoch 00001: val_loss improved from inf to 0.97181, saving model to model/dogs_vs_cats-cnn-01-0.9718.hdf5
# 1777/1777 [==============================] - 28s 16ms/sample - loss: 0.6932 - accuracy: 0.6134 - val_loss: 0.9718 - val_accuracy: 0.0000e+00
# Epoch 2/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6468 - accuracy: 0.6250
# Epoch 00002: val_loss did not improve from 0.97181
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.6464 - accuracy: 0.6252 - val_loss: 1.0314 - val_accuracy: 0.0000e+00
# Epoch 3/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6478 - accuracy: 0.6256
# Epoch 00003: val_loss improved from 0.97181 to 0.81065, saving model to model/dogs_vs_cats-cnn-03-0.8107.hdf5
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.6476 - accuracy: 0.6258 - val_loss: 0.8107 - val_accuracy: 0.0045
# Epoch 4/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.6038 - accuracy: 0.6631
# Epoch 00004: val_loss improved from 0.81065 to 0.70651, saving model to model/dogs_vs_cats-cnn-04-0.7065.hdf5
# 1777/1777 [==============================] - 27s 15ms/sample - loss: 0.6044 - accuracy: 0.6624 - val_loss: 0.7065 - val_accuracy: 0.6045
# Epoch 5/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.5921 - accuracy: 0.6693
# Epoch 00005: val_loss did not improve from 0.70651
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.5917 - accuracy: 0.6708 - val_loss: 0.7491 - val_accuracy: 0.4517
# Epoch 6/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.5331 - accuracy: 0.7347
# Epoch 00006: val_loss did not improve from 0.70651
# 1777/1777 [==============================] - 26s 15ms/sample - loss: 0.5348 - accuracy: 0.7338 - val_loss: 1.2323 - val_accuracy: 0.3079
# Epoch 7/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.5255 - accuracy: 0.7364
# Epoch 00007: val_loss did not improve from 0.70651
# 1777/1777 [==============================] - 26s 14ms/sample - loss: 0.5246 - accuracy: 0.7378 - val_loss: 0.9677 - val_accuracy: 0.3169
# Epoch 8/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.4742 - accuracy: 0.7716
# Epoch 00008: val_loss did not improve from 0.70651
# 1777/1777 [==============================] - 26s 14ms/sample - loss: 0.4734 - accuracy: 0.7727 - val_loss: 0.9617 - val_accuracy: 0.4876
# Epoch 9/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.4019 - accuracy: 0.8068
# Epoch 00009: val_loss did not improve from 0.70651
# 1777/1777 [==============================] - 26s 14ms/sample - loss: 0.4017 - accuracy: 0.8070 - val_loss: 0.7945 - val_accuracy: 0.5933
# Epoch 10/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.3176 - accuracy: 0.8585
# Epoch 00010: val_loss did not improve from 0.70651
# 1777/1777 [==============================] - 26s 14ms/sample - loss: 0.3162 - accuracy: 0.8588 - val_loss: 1.0903 - val_accuracy: 0.5640
# Epoch 11/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.2402 - accuracy: 0.8949
# Epoch 00011: val_loss did not improve from 0.70651
# 1777/1777 [==============================] - 26s 14ms/sample - loss: 0.2391 - accuracy: 0.8959 - val_loss: 1.5250 - val_accuracy: 0.4517
# Epoch 12/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.1858 - accuracy: 0.9239
# Epoch 00012: val_loss did not improve from 0.70651
# 1777/1777 [==============================] - 26s 14ms/sample - loss: 0.1849 - accuracy: 0.9246 - val_loss: 1.4080 - val_accuracy: 0.6067
# Epoch 13/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.1398 - accuracy: 0.9489
# Epoch 00013: val_loss did not improve from 0.70651
# 1777/1777 [==============================] - 26s 14ms/sample - loss: 0.1409 - accuracy: 0.9482 - val_loss: 1.1548 - val_accuracy: 0.5865
# Epoch 14/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0827 - accuracy: 0.9682
# Epoch 00014: val_loss did not improve from 0.70651
# 1777/1777 [==============================] - 25s 14ms/sample - loss: 0.0825 - accuracy: 0.9679 - val_loss: 1.3610 - val_accuracy: 0.6787

# %%
from tensorflow.keras.models import load_model
del model
model = load_model('model/dogs_vs_cats-cnn-04-0.7065.hdf5')

# %%
scores = model.evaluate(X_test, Y_test, verbose=2)
print('MODEL ACCURACY: %.5f' % scores[1])
# Out:
# 1222/1222 - 6s - loss: 0.6340 - accuracy: 0.6399
# MODEL ACCURACY: 0.63993
