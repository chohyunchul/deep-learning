# %% [markdown]
# # Dogs vs Cats

# %% [markdown]
# # Kaggle Dataset의 일부를 이용한 개, 고양이 구분

# %% [markdown]
# # Dog Image:1,111개, Cat image:1,111개, 총 2,222개

# %% [markdown]
# # 출처 : pontoregende GitHub

# %% [markdown]
# ## one-hot encoding -> logistic regreesion

# %%
import numpy as np
from glob import glob
import cv2, os, random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
path = 'dataset/train'

# %%
# seed 값 설정
seed = 0
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# ## Train set 만들기

# %%
## used for resize and in our model
ROW, COL = 96, 96  # 사진마다 사이즈가 달라서 통일시켜준다
 
dogs, cats = [], []    # x y 파일을 준비한다.
y_dogs, y_cats = [], []

# %%
dog_path = os.path.join(path, 'dog.5*')   # 도그 5 몇개가 있는지 확인한다.
len(glob(dog_path))
# Out:
# 1111

# %%
## Load some our dog images (1,111 개 이미지)
dog_path = os.path.join(path, 'dog.5*')
for dog_img in glob(dog_path):
    dog = cv2.imread(dog_img)  # 이미지 일고
    dog = cv2.cvtColor(dog, cv2.COLOR_BGR2GRAY)  # 컬러 입히고
    dog = cv2.resize(dog, (ROW, COL))  # 96 사이즈로 리사이즈
    dog = image.img_to_array(dog)
    dogs.append(dog)

# %%
## Load some our cat images (1,111 개 이미지)
cat_path = os.path.join(path, 'cat.5*')
for cat_img in glob(cat_path):
    cat = cv2.imread(cat_img)
    cat = cv2.cvtColor(cat, cv2.COLOR_BGR2GRAY)
    cat = cv2.resize(cat, (ROW, COL))
    cat = image.img_to_array(cat)
    cats.append(cat)

# %%
classes = ['dog', 'cat']

# %%
# 이미지가 제대로 들어갔는지 확인한다.
plt.figure(figsize=(12,8))
for i in range(5):
    plt.subplot(1, 5, i+1)
    img = image.array_to_img(random.choice(dogs))
    plt.imshow(img, cmap=plt.get_cmap('gray'))
    
    plt.axis('off')
    plt.title('It should be a {}.'.format(classes[0]))
plt.show()

# %%
plt.figure(figsize=(12,8))
for i in range(5):
    plt.subplot(1, 5, i+1)
    img = image.array_to_img(random.choice(cats))
    plt.imshow(img, cmap=plt.get_cmap('gray'))

    plt.axis('off')
    plt.title('It should be a {}.'.format(classes[1]))
plt.show()

# %%
## just change the labels for 0 and  1   # 사진 파일은 0과 1로 변경한다.
y_dogs =[1 for item in enumerate(dogs)]
y_cats =[0 for item in enumerate(cats)]

# %%
y_dogs[0], y_cats[0]
# Out:
# (1, 0)

# %%
## converting everything to Numpy array to fit in our model
## them creating a X and target file like we used to see
## in Machine and Deep Learning models
dogs = np.asarray(dogs).astype('float32') / 255
cats = np.asarray(cats).astype('float32') / 255
y_dogs = np.asarray(y_dogs).astype('int32')
y_cats = np.asarray(y_cats).astype('int32')

# %%
X_train = np.concatenate((dogs,cats), axis=0)
Y_train = np.concatenate((y_dogs, y_cats), axis=0)

# %%
X_train.shape, Y_train.shape
# Out:
# ((2222, 96, 96, 1), (2222,))

# %%
len(X_train)
# Out:
# 2222

# %% [markdown]
# # test set dog vs cat 만들기

# %%
dogs, cats = [], []    # x y 파일을 준비한다.
y_dogs, y_cats = [], []

# %%
dog_path = os.path.join(path, 'cat.12*')   # 도그 5 몇개가 있는지 확인한다.
len(glob(dog_path))
# Out:
# 611

# %%
## Load some our dog images (1,111 개 이미지)
dog_path = os.path.join(path, 'dog.12*')
for dog_img in glob(dog_path):
    dog = cv2.imread(dog_img)  # 이미지 일고
    dog = cv2.cvtColor(dog, cv2.COLOR_BGR2GRAY)  # 컬러 입히고
    dog = cv2.resize(dog, (ROW, COL))  # 96 사이즈로 리사이즈
    dog = image.img_to_array(dog)
    dogs.append(dog)

# %%
## Load some our cat images (1,111 개 이미지)
cat_path = os.path.join(path, 'cat.12*')
for cat_img in glob(cat_path):
    cat = cv2.imread(cat_img)
    cat = cv2.cvtColor(cat, cv2.COLOR_BGR2GRAY)
    cat = cv2.resize(cat, (ROW, COL))
    cat = image.img_to_array(cat)
    cats.append(cat)

# %%
classes1 = ['dog', 'cat']

# %%
# 이미지가 제대로 들어갔는지 확인한다.
plt.figure(figsize=(12,8))
for i in range(5):
    plt.subplot(1, 5, i+1)
    img = image.array_to_img(random.choice(dogs))
    plt.imshow(img, cmap=plt.get_cmap('gray'))
    
    plt.axis('off')
    plt.title('It should be a {}.'.format(classes1[0]))
plt.show()

# %%
plt.figure(figsize=(12,8))
for i in range(5):
    plt.subplot(1, 5, i+1)
    img = image.array_to_img(random.choice(cats))
    plt.imshow(img, cmap=plt.get_cmap('gray'))

    plt.axis('off')
    plt.title('It should be a {}.'.format(classes1[1]))
plt.show()

# %%
y_dogs =[1 for item in enumerate(dogs)]
y_cats =[0 for item in enumerate(cats)]

# %%
## converting everything to Numpy array to fit in our model
## them creating a X and target file like we used to see
## in Machine and Deep Learning models
dogs = np.asarray(dogs).astype('float32') / 255
cats = np.asarray(cats).astype('float32') / 255
y_dogs = np.asarray(y_dogs).astype('int32')
y_cats = np.asarray(y_cats).astype('int32')

# %%
dogs.shape
# Out:
# (611, 96, 96, 1)

# %%
X_test = np.concatenate((dogs,cats), axis=0)
Y_test = np.concatenate((y_dogs, y_cats), axis=0)

# %%
X_test.shape
# Out:
# (1222, 96, 96, 1)

# %%
len(X_test)
# Out:
# 1222

# %%
## here is our model as a CNN
model = Sequential([
    Conv2D(32, (3,3), padding='same', input_shape=(ROW, COL, 1), 
           activation='relu'),
    Conv2D(32, (3,3), padding='same', activation='elu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.25),
    Conv2D(64, (3,3), padding='same', activation='elu'),
    Conv2D(64, (3,3), padding='same', activation='elu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(.25),
    Flatten(),
    Dense(1000, activation='elu'),
    Dropout(.5),
    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 96, 96, 32)        320
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 96, 96, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 48, 48, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 48, 48, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 48, 48, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 48, 48, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 24, 24, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 36864)             0
# _________________________________________________________________
# dense (Dense)                (None, 1000)              36865000
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1000)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 1001
# =================================================================
# Total params: 36,930,993
# Trainable params: 36,930,993
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 'adam' Adam() 두가지 방법이 있음
model.compile(loss='binary_crossentropy', 
              optimizer=Adam(), metrics=['accuracy'])

# %%
# to save checkpoint to use later
modelpath = "model/dogs_vs_cats-cnn-{epoch:02d}-{val_loss:.4f}.hdf5"
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', 
                               verbose=1, save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10)

# %% [markdown]
# # 모델 학습

# %%
model.fit(X_train, Y_train, batch_size=32, epochs=40, validation_split=0.2, shuffle=True,
          callbacks=[checkpointer])
# Out:
# Train on 1777 samples, validate on 445 samples
# Epoch 1/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.9919 - accuracy: 0.5903
# Epoch 00001: val_loss improved from inf to 0.95558, saving model to model/dogs_vs_cats-cnn-01-0.9556.hdf5
# 1777/1777 [==============================] - 35s 20ms/sample - loss: 0.9886 - accuracy: 0.5914 - val_loss: 0.9556 - val_accuracy: 0.2876
# Epoch 2/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.5614 - accuracy: 0.7057
# Epoch 00002: val_loss improved from 0.95558 to 0.84731, saving model to model/dogs_vs_cats-cnn-02-0.8473.hdf5
# 1777/1777 [==============================] - 34s 19ms/sample - loss: 0.5605 - accuracy: 0.7068 - val_loss: 0.8473 - val_accuracy: 0.4337
# Epoch 3/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.4802 - accuracy: 0.7631
# Epoch 00003: val_loss improved from 0.84731 to 0.49234, saving model to model/dogs_vs_cats-cnn-03-0.4923.hdf5
# 1777/1777 [==============================] - 34s 19ms/sample - loss: 0.4792 - accuracy: 0.7636 - val_loss: 0.4923 - val_accuracy: 0.7798
# Epoch 4/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.4060 - accuracy: 0.8136
# Epoch 00004: val_loss did not improve from 0.49234
# 1777/1777 [==============================] - 53s 30ms/sample - loss: 0.4062 - accuracy: 0.8132 - val_loss: 0.7875 - val_accuracy: 0.6292
# Epoch 5/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.2765 - accuracy: 0.8920
# Epoch 00005: val_loss did not improve from 0.49234
# 1777/1777 [==============================] - 56s 32ms/sample - loss: 0.2764 - accuracy: 0.8914 - val_loss: 1.1029 - val_accuracy: 0.5573
# Epoch 6/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.2139 - accuracy: 0.9074
# Epoch 00006: val_loss did not improve from 0.49234
# 1777/1777 [==============================] - 56s 32ms/sample - loss: 0.2166 - accuracy: 0.9066 - val_loss: 1.4389 - val_accuracy: 0.5213
# Epoch 7/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.1426 - accuracy: 0.9449
# Epoch 00007: val_loss did not improve from 0.49234
# 1777/1777 [==============================] - 55s 31ms/sample - loss: 0.1436 - accuracy: 0.9437 - val_loss: 1.8418 - val_accuracy: 0.5573
# Epoch 8/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.1556 - accuracy: 0.9415
# Epoch 00008: val_loss did not improve from 0.49234
# 1777/1777 [==============================] - 56s 31ms/sample - loss: 0.1556 - accuracy: 0.9415 - val_loss: 1.6314 - val_accuracy: 0.5933
# Epoch 9/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.1844 - accuracy: 0.9239
# Epoch 00009: val_loss did not improve from 0.49234
# 1777/1777 [==============================] - 55s 31ms/sample - loss: 0.1830 - accuracy: 0.9246 - val_loss: 1.7560 - val_accuracy: 0.5865
# Epoch 10/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.1131 - accuracy: 0.9557
# Epoch 00010: val_loss did not improve from 0.49234
# 1777/1777 [==============================] - 56s 32ms/sample - loss: 0.1129 - accuracy: 0.9555 - val_loss: 2.3891 - val_accuracy: 0.5056
# Epoch 11/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0526 - accuracy: 0.9778
# Epoch 00011: val_loss did not improve from 0.49234
# 1777/1777 [==============================] - 56s 32ms/sample - loss: 0.0524 - accuracy: 0.9781 - val_loss: 1.9640 - val_accuracy: 0.6225
# Epoch 12/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0410 - accuracy: 0.9852
# Epoch 00012: val_loss did not improve from 0.49234
# 1777/1777 [==============================] - 54s 30ms/sample - loss: 0.0407 - accuracy: 0.9854 - val_loss: 1.5749 - val_accuracy: 0.6944
# Epoch 13/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0478 - accuracy: 0.9801
# Epoch 00013: val_loss did not improve from 0.49234
# 1777/1777 [==============================] - 56s 32ms/sample - loss: 0.0474 - accuracy: 0.9803 - val_loss: 3.8924 - val_accuracy: 0.4494
# Epoch 14/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0432 - accuracy: 0.9835
# Epoch 00014: val_loss did not improve from 0.49234
# 1777/1777 [==============================] - 56s 31ms/sample - loss: 0.0430 - accuracy: 0.9837 - val_loss: 1.7463 - val_accuracy: 0.6719
# Epoch 15/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0367 - accuracy: 0.9881
# Epoch 00015: val_loss did not improve from 0.49234
# 1777/1777 [==============================] - 55s 31ms/sample - loss: 0.0365 - accuracy: 0.9882 - val_loss: 2.5397 - val_accuracy: 0.5798
# Epoch 16/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0351 - accuracy: 0.9875
# Epoch 00016: val_loss did not improve from 0.49234
# 1777/1777 [==============================] - 55s 31ms/sample - loss: 0.0348 - accuracy: 0.9876 - val_loss: 5.8073 - val_accuracy: 0.3438
# Epoch 17/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.1505 - accuracy: 0.9511
# Epoch 00017: val_loss did not improve from 0.49234
# 1777/1777 [==============================] - 55s 31ms/sample - loss: 0.1518 - accuracy: 0.9510 - val_loss: 5.1440 - val_accuracy: 0.4157
# Epoch 18/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.2783 - accuracy: 0.9187
# Epoch 00018: val_loss did not improve from 0.49234
# 1777/1777 [==============================] - 56s 31ms/sample - loss: 0.2764 - accuracy: 0.9190 - val_loss: 2.6763 - val_accuracy: 0.4989
# Epoch 19/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.1171 - accuracy: 0.9557
# Epoch 00019: val_loss did not improve from 0.49234
# 1777/1777 [==============================] - 56s 32ms/sample - loss: 0.1161 - accuracy: 0.9561 - val_loss: 2.2096 - val_accuracy: 0.5640
# Epoch 20/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0370 - accuracy: 0.9886
# Epoch 00020: val_loss did not improve from 0.49234
# 1777/1777 [==============================] - 56s 31ms/sample - loss: 0.0367 - accuracy: 0.9887 - val_loss: 2.0446 - val_accuracy: 0.6742
# Epoch 21/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0188 - accuracy: 0.9932
# Epoch 00021: val_loss did not improve from 0.49234
# 1777/1777 [==============================] - 56s 31ms/sample - loss: 0.0186 - accuracy: 0.9932 - val_loss: 2.2923 - val_accuracy: 0.6449
# Epoch 22/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0322 - accuracy: 0.9892
# Epoch 00022: val_loss did not improve from 0.49234
# 1777/1777 [==============================] - 56s 31ms/sample - loss: 0.0319 - accuracy: 0.9893 - val_loss: 3.9980 - val_accuracy: 0.4697
# Epoch 23/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0241 - accuracy: 0.9920
# Epoch 00023: val_loss did not improve from 0.49234
# 1777/1777 [==============================] - 56s 32ms/sample - loss: 0.0239 - accuracy: 0.9921 - val_loss: 3.3540 - val_accuracy: 0.5640
# Epoch 24/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0126 - accuracy: 0.9949
# Epoch 00024: val_loss did not improve from 0.49234
# 1777/1777 [==============================] - 48s 27ms/sample - loss: 0.0125 - accuracy: 0.9949 - val_loss: 6.0211 - val_accuracy: 0.3775
# Epoch 25/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0188 - accuracy: 0.9955
# Epoch 00025: val_loss did not improve from 0.49234
# 1777/1777 [==============================] - 30s 17ms/sample - loss: 0.0186 - accuracy: 0.9955 - val_loss: 4.2845 - val_accuracy: 0.5079
# Epoch 26/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0182 - accuracy: 0.9937
# Epoch 00026: val_loss did not improve from 0.49234
# 1777/1777 [==============================] - 30s 17ms/sample - loss: 0.0185 - accuracy: 0.9932 - val_loss: 3.5752 - val_accuracy: 0.5461
# Epoch 27/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0180 - accuracy: 0.9943
# Epoch 00027: val_loss did not improve from 0.49234
# 1777/1777 [==============================] - 30s 17ms/sample - loss: 0.0178 - accuracy: 0.9944 - val_loss: 3.4160 - val_accuracy: 0.5708
# Epoch 28/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0149 - accuracy: 0.9949
# Epoch 00028: val_loss did not improve from 0.49234
# 1777/1777 [==============================] - 30s 17ms/sample - loss: 0.0148 - accuracy: 0.9949 - val_loss: 4.4196 - val_accuracy: 0.5191
# Epoch 29/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0196 - accuracy: 0.9909
# Epoch 00029: val_loss did not improve from 0.49234
# 1777/1777 [==============================] - 30s 17ms/sample - loss: 0.0196 - accuracy: 0.9910 - val_loss: 3.3397 - val_accuracy: 0.5573
# Epoch 30/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0266 - accuracy: 0.9909
# Epoch 00030: val_loss did not improve from 0.49234
# 1777/1777 [==============================] - 30s 17ms/sample - loss: 0.0263 - accuracy: 0.9910 - val_loss: 3.0394 - val_accuracy: 0.6472
# Epoch 31/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0261 - accuracy: 0.9903
# Epoch 00031: val_loss did not improve from 0.49234
# 1777/1777 [==============================] - 30s 17ms/sample - loss: 0.0277 - accuracy: 0.9899 - val_loss: 3.7850 - val_accuracy: 0.5483
# Epoch 32/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0271 - accuracy: 0.9886
# Epoch 00032: val_loss did not improve from 0.49234
# 1777/1777 [==============================] - 30s 17ms/sample - loss: 0.0269 - accuracy: 0.9887 - val_loss: 4.5844 - val_accuracy: 0.5730
# Epoch 33/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.1168 - accuracy: 0.9648
# Epoch 00033: val_loss did not improve from 0.49234
# 1777/1777 [==============================] - 30s 17ms/sample - loss: 0.1197 - accuracy: 0.9640 - val_loss: 2.1543 - val_accuracy: 0.7169
# Epoch 34/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.2538 - accuracy: 0.9398
# Epoch 00034: val_loss did not improve from 0.49234
# 1777/1777 [==============================] - 30s 17ms/sample - loss: 0.2539 - accuracy: 0.9387 - val_loss: 4.3818 - val_accuracy: 0.5191
# Epoch 35/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.1830 - accuracy: 0.9494
# Epoch 00035: val_loss did not improve from 0.49234
# 1777/1777 [==============================] - 30s 17ms/sample - loss: 0.1817 - accuracy: 0.9499 - val_loss: 4.2254 - val_accuracy: 0.5236
# Epoch 36/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.1158 - accuracy: 0.9665
# Epoch 00036: val_loss did not improve from 0.49234
# 1777/1777 [==============================] - 30s 17ms/sample - loss: 0.1166 - accuracy: 0.9662 - val_loss: 2.9094 - val_accuracy: 0.5910
# Epoch 37/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0448 - accuracy: 0.9824
# Epoch 00037: val_loss did not improve from 0.49234
# 1777/1777 [==============================] - 30s 17ms/sample - loss: 0.0444 - accuracy: 0.9826 - val_loss: 3.7764 - val_accuracy: 0.5753
# Epoch 38/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0286 - accuracy: 0.9932
# Epoch 00038: val_loss did not improve from 0.49234
# 1777/1777 [==============================] - 30s 17ms/sample - loss: 0.0283 - accuracy: 0.9932 - val_loss: 4.6167 - val_accuracy: 0.4944
# Epoch 39/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0237 - accuracy: 0.9915
# Epoch 00039: val_loss did not improve from 0.49234
# 1777/1777 [==============================] - 30s 17ms/sample - loss: 0.0235 - accuracy: 0.9916 - val_loss: 2.9757 - val_accuracy: 0.6360
# Epoch 40/40
# 1760/1777 [============================>.] - ETA: 0s - loss: 0.0301 - accuracy: 0.9920
# Epoch 00040: val_loss did not improve from 0.49234
# 1777/1777 [==============================] - 30s 17ms/sample - loss: 0.0298 - accuracy: 0.9921 - val_loss: 3.6571 - val_accuracy: 0.5258

# %%
from tensorflow.keras.models import load_model
del model
model = load_model('model/dogs_vs_cats-cnn-03-0.4923.hdf5')

# %%
scores = model.evaluate(X_test, Y_test, verbose=2)
print('MODEL ACCURACY: %.5f' % scores[1])
# Out:
# 1222/1222 - 4s - loss: 0.7007 - accuracy: 0.6342
# MODEL ACCURACY: 0.63421
